# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
var_C = np.logspace(-3,3,10).round(3)
np.printoptions(suppress=True)
var_C
X_vals = np.arange(var_C.shape[0])

# %%
plt.bar(X_vals,var_C)
# plt.annotate(xycoords=(zip(X_vals,var_C)),text=var_C)
# Out:
# <BarContainer object of 10 artists>

# %%
np.exp(3) == np.logspace(-3,3,10)[-1]
# Out:
# False

# %%
np.log(3)
# Out:
# 1.0986122886681098

# %%
np.logspace(-3,4,num=10)
# Out:
# array([1.00000000e-03, 5.99484250e-03, 3.59381366e-02, 2.15443469e-01,
#        1.29154967e+00, 7.74263683e+00, 4.64158883e+01, 2.78255940e+02,
#        1.66810054e+03, 1.00000000e+04])
